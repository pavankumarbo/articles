# %%
import seaborn as sns
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
sns.set_style('whitegrid')

# %%
tips = pd.read_csv('tips.csv')

# %%
tips["date"] = pd.date_range(start='7/31/2020', periods=tips.shape[0], freq='6h')

# %%
tips = tips.rename(columns={'size':'table_size'})

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  table_size  \
# 0       16.99  1.01  Female     No  Sun  Dinner           2
# 1       10.34  1.66    Male     No  Sun  Dinner           3
# 2       21.01  3.50    Male     No  Sun  Dinner           3
# 3       23.68  3.31    Male     No  Sun  Dinner           2
# 4       24.59  3.61  Female     No  Sun  Dinner           4
#
#                  date
# 0 2020-07-31 00:00:00
# 1 2020-07-31 06:00:00
# 2 2020-07-31 12:00:00
# 3 2020-07-31 18:00:00
# 4 2020-08-01 00:00:00

# %%
sns.set_style('whitegrid')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('White grid Style', fontsize=15);
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/whitegrid.png')

# %%
# Out:
# seaborn.axisgrid.PairGrid

# %%
sns.set_style('white')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('White Style', fontsize=15);
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/white.png');

# %%
sns.set_style('darkgrid')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('Dark Grid Style', fontsize=15);
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/DarkGrid.png')

# %%
sns.set_style('dark')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('Dark Style', fontsize=15);
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/dark.png')

# %%
sns.set_style('ticks')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('Ticks Style', fontsize=15);
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/ticks.png')

# %% [markdown]
# ## Numerical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('Tip Amount Distribution');
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_hist_dist.png')

# %% [raw]
# optional parameters:
# rug,kde

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip,kde=False)
g.set_title('Tip Amount Histogram');
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_hist.png')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip,rug=True)
g.set_title('Tip Amount Distribution with rug');
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_hist_dist_rug.png')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(tips.tip)
g.set_title('Tip Amount Probablity Distribution');
g.set_xlabel('Tip Amount')
g.set_ylabel('probability')
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/axes_subplot_demo.png');

# %% [markdown]
# ## One Category

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",kind='count',order=['Thur','Fri','Sun','Sat'],data=tips);
g.fig.suptitle("Frequency of days in the tips dataset [Count Plot]",y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cat_count.png',bbox_inches='tight')

# %% [markdown]
# ## Two Categorical Variables

# %% [markdown]
# ## Two Numerical Variables

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",data=tips,kind='scatter')
g.fig.suptitle('Relationship between continuous variables [Scatter Plot]',y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_scatter.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",data=tips,kind='scatter');
g.axes[0,0].set_title('Relationship between continuous variables [Scatter Plot]');
g.axes[0,0].set_xlabel('Total Bill Amount');
g.axes[0,0].set_ylabel('Tip Amount');
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/facetgrid_demo.png',bbox_inches='tight');

# %%
fig = plt.figure(figsize=(8,5))
g = sns.jointplot(x="total_bill",y='tip',data=tips,kind='kde');
g.fig.suptitle('Density distribution among tips and total_bill [KDE Plot]',y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_kde.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(15,5))
g = sns.lineplot(x="date",y="total_bill",data=tips)
g.set_title('Total bill amount over time [Line plot]')
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_timeseries.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.jointplot(x="total_bill",y="tip",data=tips)
g.fig.suptitle('Relationship b/w tip and total amount along with distributions [Scatter Plot + Histograms]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_scatter_hist.png',bbox_inches='tight');

# %%
fig = plt.figure(figsize=(8,5))
g = sns.lmplot(x="total_bill",y="tip",data=tips)
g.fig.suptitle('Relationship b/w tip and total_bill [Scatter Plot + Regression Line]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_scatter_regression_line.png',bbox_inches='tight')

# %% [markdown]
# ## 2 numerical, 1 categorical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",hue='sex',kind='scatter',data=tips);
g.fig.suptitle('Relationship b/w totalbill and tip distinguished by gender [Scatter Plot]',y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_1_cat_scatter_hue_colot.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",col='sex',kind='scatter',data=tips);
g.fig.suptitle('Relationship between totalbill and tip by gender [Scatter Plot]',y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_1_cat_scatter_by_col.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",style='sex',kind='scatter',data=tips)
g.fig.suptitle('Relationship b/w totalbill distinguished by gender as marker [Scatter Plot]',y=1.05);
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_1_cat_hue_marker.png',bbox_inches='tight')

# %% [markdown]
# ## Three Numerical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",size='table_size',kind='scatter',data=tips)
g.fig.suptitle('total bill vs tip distinguished by table size [Scatter Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/2_cont_scatter_size.png',bbox_inches='tight')

# %% [markdown]
# ## 3 numerical 1 categorical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.relplot(x="total_bill",y="tip",col='sex',size='table_size',kind='scatter',data=tips)
g.fig.suptitle('Total bill vs tip by gender distinguished by table size [Scatter Plot]',y=1.03)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/3_cont_1_cat_scatter_size_by_col.png',bbox_inches='tight')

# %% [markdown]
# ## One Numerical One Categorical

# %%
# barplot
# strip plot
# box plot
# violin plot
# pointplot

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='bar',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('Tip amount by day of week [Bar Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_1_cat_bar.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='swarm',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('Tip amount by day along with tip distribution [Swarm Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_1_cat_swarm.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='strip',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('Tip amount by day along with tips as scatter [Strip Plot]',y=1.03)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_1_cat_strip.png',bbox_inches='tight')

# %% [raw]
# optional parameters:
# ci,order

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='violin',order=['Thur','Fri','Sun','Sat'],data=tips)
g.fig.suptitle('Tips distributions by day [Violin Plot]')
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_1_cat_violing.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='point',order=['Thur','Fri','Sun','Sat'],data=tips,capsize=0.5)
g.fig.suptitle('IQR Range of tip by day [Point Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cat_1_cont_point_plot.png',bbox_inches='tight')

# %% [markdown]
# ## One numerical Two categorical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='bar',col='smoker',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('Tip amount by day of week by smoker/non-smoker [Bar Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_2_cat_by_col.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='bar',hue='smoker',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('TIps by day with smoker/non-smoker subgroup [Grouped Bar Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_2_cat_by_subgroup.png',bbox_inches='tight')

# %% [markdown]
# ## One Numerical Three Categorical

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="day",y="tip",kind='bar',hue='smoker',col='sex',order=['Thur','Fri','Sun','Sat'],ci=False,data=tips)
g.fig.suptitle('TIps by day with smoker/non-smoker subgroup by gender [Grouped Bar Plot]',y=1.05)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/1_cont_2_cat_by_subgroup_by_col.png',bbox_inches='tight')

# %% [markdown]
# ## More than three numerical variables

# %%
fig = plt.figure(figsize=(8,5))
g = sns.heatmap(tips.corr());
g.set_title('correlation between continuous variables [Heat Map]')
fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/heatmap.png',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.pairplot(tips);
g.fig.suptitle('Relationship between continuous variables [Patiplot]',y=1.03)
g.fig.savefig('/Users/pavankumarboinapalli/Desktop/seaborn/pairplot.png',bbox_inches='tight')
